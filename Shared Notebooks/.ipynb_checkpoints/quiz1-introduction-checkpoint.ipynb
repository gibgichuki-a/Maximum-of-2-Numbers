# %% [markdown]
# ## 1. What will be the output of the following Python code?
#
# - a) [1] [2] [3]
# - b) [1] [1, 2] [1, 2, 3]
# - c) [1, 2, 3]
# - d) 1 2 3

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'locals()'],
#  '_oh': {},
#  '_dh': [PosixPath('/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals')],
#  'In': ['', 'locals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x73742db9b350>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x73742b3629c0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x73742b3629c0>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals/quiz1-introduction.ipynb',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'locals()'}

# %%
def f(i, values=[]):
    values.append(i)
    return values

f(1)
f(2)
v = f(3)
print(v)
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'locals()',
#   'def f(i, values=[]):\n    values.append(i)\n    return values\n\nf(1)\nlocals()'],
#  '_oh': {1: {...}},
#  '_dh': [PosixPath('/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals')],
#  'In': ['',
#   'locals()',
#   'def f(i, values=[]):\n    values.append(i)\n    return values\n\nf(1)\nlocals()'],
#  'Out': {1: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x73742db9b350>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x73742b3629c0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x73742b3629c0>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals/quiz1-introduction.ipynb',
#  '_i': 'locals()',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'locals()',
#  '_1': {...},
#  '_i2': 'def f(i, values=[]):\n    values.append(i)\n    return values\n\nf(1)\nlocals()',
#  'f': <function __main__.f(i, values=[1])>}

# %% [markdown]
# ## 2. What will be the output of the following Python code?
#
# - a) None
# - b) 1
# - c) 2
# - d) Error

# %%
names1 = ['Amir', 'Bala', 'Chales']
if 'amir' in names1:
    print(1)
else:
    print(2)
# Out:
# 2

# %% [markdown]
# # 3. What will be the output of the following Python code?
#
# - a) None
# - b) a
# - c) b
# - d) c

# %%
names1 = ['Amir', 'Bala', 'Charlie']
names2 = [name.lower() for name in names1]
print(names2[2][0])
# Out:
# c

# %% [markdown]
# # 4.What will be the output of the following Python code?
#
# - a) 4
# - b) 5
# - c) 8
# - d) 12

# %%
numbers = [1, 2, 3, 4]
numbers.append([5,6,7,8])
print(len(numbers))
print(numbers)
# Out:
# 5
# [1, 2, 3, 4, [5, 6, 7, 8]]

# %% [markdown]
# # 5. To which of the following the “in” operator can be used to check if an item
#
# - a) Lists
# - b) Dictionary
# - c) Set
# - d) All of the mentioned

# %% [markdown]
# # 6. What will be the output of the following Python code?
#
# - a) 2
# - b) 4
# - c) 5
# - d) 8

# %%
list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]
print(len(list1 + list2))
list1 + list2
# Out:
# 8
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# # 7. What will be the output of the following Python code?
#
# - a) 1
# - b) 4
# - c) 5
# - d) 8

# %%
def addItem(listParam):
    listParam += [1]

mylist = [1, 2, 3, 4]
addItem(mylist)
print(len(mylist))
# Out:
# 5

# %% [markdown]
# # 8. What will be the output of the following Python code?
#
# - a) None [3, 4, 5]
# - b) None [1, 2, 3]
# - c) [3, 4, 5] [1, 2, 3]
# - d) [3, 4, 5] None

# %%
def increment_items(L, increment):
    i = 0
    while i < len(L):
        L[i] = L[i] + increment
        i = i + 1

values = [1, 2, 3]
print(increment_items(values, 2))
print(values)
# Out:
# None
# [3, 4, 5]

# %% [markdown]
# # 9. What will be the output of the following Python code?
#
# - a) Return a list containing every third item from L starting at index 0
# - b) Return an empty list
# - c) Return a list containing every third index from L starting at index 0
# - d) Return a list containing the items from L starting from index 0, omitting every third item

# %%
def example(L):
    """ (list) -> list """

    i = 0
    result = []
    while i < len(L):
        result.append(L[i])
        i = i + 3
    
    return result

l = [1, 2, 3, 4]
res = example(l)
print(res)
# Out:
# [1, 4]

# %% [markdown]
# # 10. What will be the output of the following Python code?
#
# - a) [‘carrot’, ‘celery’, ‘broccoli’, ‘potato’, ‘asparagus’]
# - b) [‘carrot’, ‘celery’, ‘potato’, ‘asparagus’]
# - c) [‘carrot’, ‘broccoli’, ‘celery’, ‘potato’, ‘asparagus’]
# - d) [‘celery’, ‘carrot’, ‘broccoli’, ‘potato’, ‘asparagus’]

# %%
veggies = ['carrot', 'broccoli', 'potato', 'asparagus']
veggies.insert(veggies.index('broccoli'), 'celery')
print(veggies)
# Out:
# ['carrot', 'celery', 'broccoli', 'potato', 'asparagus']
