# %% [markdown]
# ## 1. What will be the output of the following Python code?
#
# - a) Error
# - b) 12
# - c) 15
# - d) 1512

# %%
def f1():
        x = 15
        print(x)
x = 12
f1()
# Out:
# 15

# %% [markdown]
# ## 2. What will be the output of the following Python code?
#
# - a) Error
# - b) 100
# - c) 101
# - d) 99

# %%
def f1():
        x = 100
        print(x)

x = +1
f1()
# Out:
# 100

# %% [markdown]
# # 3. What will be the output of the following Python code?
#
# - a) 13
# - b) 10
# - c) 2
# - d) 5

# %%
def san(x):
        print(x+1)
x = -2
x = 4
san(12)
# Out:
# 13

# %% [markdown]
# # 4. What will be the output of the following Python code?
#
# - a) Error
# - b) 13
# - c) \
#      13 \
#      x
# - d) x

# %%
def f1():
        global x
        x+=1
        print(x)
x = 12
print('x')
# Out:
# x

# %% [markdown]
# # 5. What will be the output of the following Python code?
#
# - a) error
# - b) hello
# - c) 16
# - d) \
# 16\
# hello

# %%
def f1(x):
        global x
        x+=1
        print(x)

f1(15)
print("hello")
# Out:
#   Cell In[18], line 2
#     global x
#     ^
# SyntaxError: name 'x' is parameter and global

# %% [markdown]
# # 6. What will be the output of the following Python code?
#
# - a) Error
# - b) 12 4
# - c) 4 12
# - d) 4 15

# %%
x = 12
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'x = 12\nlocals()'],
#  '_oh': {},
#  '_dh': [PosixPath('/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals')],
#  'In': ['', 'x = 12\nlocals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x75517a997980>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x75517a9d4170>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x75517a9d4170>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': '',
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals/quiz2-Global_vs_local.ipynb',
#  '_i': '',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'x = 12\nlocals()',
#  'x': 12}

# %%
def f1(a,b=x):
        print(a,b)

locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'x = 12\nlocals()',
#   'def f1(a,b=x):\n        print(a,b)\n\nlocals()'],
#  '_oh': {1: {...}},
#  '_dh': [PosixPath('/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals')],
#  'In': ['',
#   'x = 12\nlocals()',
#   'def f1(a,b=x):\n        print(a,b)\n\nlocals()'],
#  'Out': {1: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x75517a997980>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x75517a9d4170>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x75517a9d4170>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__vsc_ipynb_file__': '/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals/quiz2-Global_vs_local.ipynb',
#  '_i': 'x = 12\nlocals()',
#  '_ii': '',
#  '_iii': '',
#  '_i1': 'x = 12\nlocals()',
#  'x': 12,
#  '_1': {...},
#  '_i2': 'def f1(a,b=x):\n        print(a,b)\n\nlocals()',
#  'f1': <function __main__.f1(a, b=12)>}

# %%
x = 15
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'x = 12\nlocals()',
#   'def f1(a,b=x):\n        print(a,b)\n\nlocals()',
#   'x = 15\nlocals()'],
#  '_oh': {1: {...}, 2: {...}},
#  '_dh': [PosixPath('/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals')],
#  'In': ['',
#   'x = 12\nlocals()',
#   'def f1(a,b=x):\n        print(a,b)\n\nlocals()',
#   'x = 15\nlocals()'],
#  'Out': {1: {...}, 2: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x75517a997980>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x75517a9d4170>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x75517a9d4170>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': {...},
#  '___': '',
#  '__vsc_ipynb_file__': '/home/fogang/Tutoring AIMS/Reading Week - 2025-2026/1_python fundamentals/quiz2-Global_vs_local.ipynb',
#  '_i': 'def f1(a,b=x):\n        print(a,b)\n\nlocals()',
#  '_ii': 'x = 12\nlocals()',
#  '_iii': '',
#  '_i1': 'x = 12\nlocals()',
#  'x': 15,
#  '_1': {...},
#  '_i2': 'def f1(a,b=x):\n        print(a,b)\n\nlocals()',
#  'f1': <function __main__.f1(a, b=12)>,
#  '_2': {...},
#  '_i3': 'x = 15\nlocals()'}

# %%
f1(4)
locals()

# %% [markdown]
# # 7. What will be the output of the following Python code?
#
# - a)
# hello
#
#     hello
#
#     world
# - b)
# world
#
#     hello
#
#     hello
# - c)
# hello
#
#     world
#
#     world
# - d)
# world
#
#     hello
#
#     world

# %%
def f():
        global a
        print(a)
        a = "hello"
        print(a)
        
a = "world"
f()
print(a)
# Out:
# world
# hello
# hello

# %% [markdown]
# # 8. What will be the output of the following Python code?
#
# - a) [3,2,4]
# - b) [2,3,4]
# - c) Error
# - d) [3,4,2]

# %%
def f1(a,b=[]):
    b.append(a)
    return b

print(f1(2,[3,4]))
# Out:
# [3, 4, 2]

# %% [markdown]
# # 9. What will be the output of the following Python code?
#
# - a) 1 2 3 4
# - b) 5 10 15 4
# - c) 10 20 30 40
# - d) 5 10 15 40

# %%
def f(p, q, r):
    global s
    p = 10
    q = 20
    r = 30
    s = 40
    print(p,q,r,s)
p, q, r, s = 1, 2, 3, 4
f(5, 10, 15)
# Out:
# 10 20 30 40

# %% [markdown]
# # 10. What will be the output of the following Python code?
#
# - a)
# outer
#
#     error
#
# - b)
# inner
#
#     error
#
# - c)
# outer
#
#     inner
#
# - d) error

# %%
def f10(x):
    print("outer")
    def f11(a):
        print("inner")
        print(a, x)

    
f10(3)
f11(1)
# Out:
# outer
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       5         print(a, x)
#       8 f10(3)
# ----> 9 f11(1)
#
# NameError: name 'f11' is not defined

# %% [markdown]
# # 11. What will be the output of the following Python code?
#
# - a) Error
# - b) 7
# - c) 8
# - d) 15

# %%
x = 5
def f1():
    global x
    x = 4

def f2(a,b):
    global x
    return a+b+x

f1()
total = f2(1,2)
print(total)
# Out:
# 7

# %% [markdown]
# # 12. What will be the output of the following Python code?
#
# - a) 100
# - b) 90
# - c) 80
# - d) Error

# %%
x=100
def f1():
    global x
    x=90

def f2():
    global x
    x=80
    
print(x)
# Out:
# 100

# %% [markdown]
# # 13. Read the following Python code carefully and point out the global variables?
#
# - a) x
# - b) y and z
# - c) x, y and z
# - d) Neither x, nor y, nor z

# %%
y, z = 1, 2
def f():
    global x
    x = y+z

# %% [markdown]
# ## 08 Nov 2025

# %%
type(1)
# Out:
# int

# %%
t = (1,)

# %%
type(t)
# Out:
# tuple

# %%
a = (1,2,3,4)
a[1:-1]
# Out:
# (2, 3)

# %%
('check''check''check')
# Out:
# 'checkcheckcheck'

# %%
a = (2,3,4)
sum(a,3)
# Out:
# 12

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
a = (1,2) #the object is deleted from the memory
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = [(1,1),(2,4),(3,9)]

# %%
type(a)
# Out:
# list

# %%
a = (0,1,2,3,4)
b = slice(0,2)
a[b]
# Out:
# (0, 1)

# %%
 for i in range(int(2.0)):
    print (i)
# Out:
# 0
# 1

# %%
for i in range(float("inf")):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 for i in range(float("inf")):
#       2     print(i)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
for i in range [1,2,3,4]

# %%
for i in 'LOL'.join(reversed(list("abcd"))):
    print(i)
# Out:
# d
# L
# O
# L
# c
# L
# O
# L
# b
# L
# O
# L
# a

# %%
for i in ' '.join(reversed(list("abcd"))):
    print(i)
# Out:
# d
#
# c
#
# b
#
# a

# %%
x=2
for i in range(x):
    x +=1
    print(x)
# Out:
# 3
# 4

# %%
x=2
for i in range(x):
    x -=2
    print(x)
# Out:
# 0
# -2
